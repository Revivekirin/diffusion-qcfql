# %%
import h5py
import numpy as np

H_list = [5, 10, 20]   # 분석할 chunk 길이 후보들
all_stats = {H: [] for H in H_list}
dataset_path = "/home/robros/git/diffusion-qcfql/robomimic/dataset/transport/mh/low_dim_v15.hdf5"

with h5py.File(dataset_path, "r") as f:
    demos = sorted(list(f["data"].keys()))  # ["demo_0", "demo_1", ...]
    
    for ep in demos:
        rew = np.array(f[f"data/{ep}/rewards"])   # [T]
        done = np.array(f[f"data/{ep}/dones"])    # [T] or [T,1]

        if done.ndim > 1:
            done = done.squeeze(-1)

        T = len(rew)

        for H in H_list:
            # 슬라이딩 윈도우: stride=1
            for start in range(0, T - H + 1):
                end = start + H
                r_chunk = rew[start:end]
                d_chunk = done[start:end]

                # valid mask: 중간에 done 나오면 이후는 0으로
                valid = np.ones(H, dtype=np.float32)
                for t in range(1, H):
                    if d_chunk[t-1] > 0.5:
                        valid[t:] = 0.0
                        break

                traj_return = float((r_chunk * valid).sum())

                all_stats[H].append({
                    "traj_return": traj_return,
                    "has_done": bool(d_chunk.max() > 0.5),
                    "start": start,
                    "ep": ep,
                })

# %%
all_stats
# Out:
# {5: [{'traj_return': 0.0, 'has_done': False, 'start': 0, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 1, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 2, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 3, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 4, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 5, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 6, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 7, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 8, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 9, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 10, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 11, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 12, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 13, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 14, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 15, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 16, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 17, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 18, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 19, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 20, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 21, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 22, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 23, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 24, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 25, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 26, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 27, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 28, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 29, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 30, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 31, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 32, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 33, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 34, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 35, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 36, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 37, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 38, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 39, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 40, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 41, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 42, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 43, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 44, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 45, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 46, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 47, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 48, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 49, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 50, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 51, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 52, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 53, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 54, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 55, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 56, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 57, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 58, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 59, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 60, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 61, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 62, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 63, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 64, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 65, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 66, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 67, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 68, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 69, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 70, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 71, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 72, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 73, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 74, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 75, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 76, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 77, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 78, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 79, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 80, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 81, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 82, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 83, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 84, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 85, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 86, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 87, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 88, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 89, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 90, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 91, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 92, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 93, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 94, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 95, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 96, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 97, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 98, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 99, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 100, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 101, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 102, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 103, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 104, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 105, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 106, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 107, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 108, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 109, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 110, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 111, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 112, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 113, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 114, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 115, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 116, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 117, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 118, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 119, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 120, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 121, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 122, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 123, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 124, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 125, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 126, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 127, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 128, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 129, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 130, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 131, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 132, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 133, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 134, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 135, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 136, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 137, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 138, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 139, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 140, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 141, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 142, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 143, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 144, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 145, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 146, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 147, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 148, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 149, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 150, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 151, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 152, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 153, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 154, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 155, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 156, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 157, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 158, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 159, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 160, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 161, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 162, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 163, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 164, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 165, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 166, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 167, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 168, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 169, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 170, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 171, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 172, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 173, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 174, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 175, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 176, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 177, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 178, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 179, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 180, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 181, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 182, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 183, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 184, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 185, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 186, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 187, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 188, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 189, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 190, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 191, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 192, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 193, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 194, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 195, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 196, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 197, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 198, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 199, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 200, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 201, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 202, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 203, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 204, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 205, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 206, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 207, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 208, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 209, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 210, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 211, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 212, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 213, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 214, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 215, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 216, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 217, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 218, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 219, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 220, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 221, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 222, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 223, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 224, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 225, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 226, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 227, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 228, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 229, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 230, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 231, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 232, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 233, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 234, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start':
 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 620, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 621, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 622, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 623, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 624, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 625, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 626, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 627, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 628, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 629, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 630, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 631, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 632, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 633, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 634, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 635, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 636, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 637, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 638, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 639, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 640, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 641, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 642, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 643, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 644, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 645, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 646, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 647, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 648, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 649, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 650, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 651, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 652, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 653, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 654, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 655, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 656, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 657, 'ep': 'demo_0'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 658, 'ep': 'demo_0'},
# ...
#   {'traj_return': 0.0, 'has_done': False, 'start': 86, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 87, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 88, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 89, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 90, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 91, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 92, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 93, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 94, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 95, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 96, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 97, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 98, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 99, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 100, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 101, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 102, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 103, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 104, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 105, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 106, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 107, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 108, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 109, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 110, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 111, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 112, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 113, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 114, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 115, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 116, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 117, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 118, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 119, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 120, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 121, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 122, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 123, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 124, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 125, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 126, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 127, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 128, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 129, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 130, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 131, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 132, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 133, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 134, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 135, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 136, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 137, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 138, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 139, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 140, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 141, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 142, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 143, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 144, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 145, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 146, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 147, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 148, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 149, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 150, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 151, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 152, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 153, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 154, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 155, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 156, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 157, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 158, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 159, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 160, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 161, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 162, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 163, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 164, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 165, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 166, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 167, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 168, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 169, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 170, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 171, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 172, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 173, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 174, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 175, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 176, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 177, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 178, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 179, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 180, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 181, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 182, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 183, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 184, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 185, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 186, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 187, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 188, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 189, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 190, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 191, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 192, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 193, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 194, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 195, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 196, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 197, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 198, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 199, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 200, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 201, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 202, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 203, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 204, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 205, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 206, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 207, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 208, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 209, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 210, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 211, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 212, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 213, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 214, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 215, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 216, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 217, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 218, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 219, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 220, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 221, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 222, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 223, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 224, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 225, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 226, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 227, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 228, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 229, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 230, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 231, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 232, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 233, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 234, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 235, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 236, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 237, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 238, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 239, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 240, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 241, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 242, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 243, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 244, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 245, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 246, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 247, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 248, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 249, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 250, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 251, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 252, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 253, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 254, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 255, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 256, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 257, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 258, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 259, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 260, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 261, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 262, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 263, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 264, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 265, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 266, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 267, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 268, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 269, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 270, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 271, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 272, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 273, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 274, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 275, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 276, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 277, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 278, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 279, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 280, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 281, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 282, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 283, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 284, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 285, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 286, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 287, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 288, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 289, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 290, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 291, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 292, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 293, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 294, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 295, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 296, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 297, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 298, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 299, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 300, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 301, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 302, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 303, 'ep': 'demo_1'},
#   {'traj_return': 0.0, 'has_done': False, 'start': 304, 'ep': 'demo_1'},
#   ...]}

# %%
import numpy as np

for i in H_list:
    stats = all_stats[i]
    returns = np.array([s["traj_return"] for s in stats])

    print("H=20, 총 chunk 수:", len(returns))
    print("min, max, mean, std:", returns.min(), returns.max(), returns.mean(), returns.std())

    # 성공 기준 잡기 (예: return > 0.5)
    success_mask = returns > 0.5
    print("성공 chunk 비율:", success_mask.mean())

    # 성공 chunk가 에피소드 어디에 몰려 있는지
    success_positions = np.array([s["start"] for s in stats])[success_mask]
    print("성공 chunk 시작 step 평균/표준편차:", success_positions.mean(),
        success_positions.std())
# Out:
# H=20, 총 chunk 수: 190100
# min, max, mean, std: 0.0 1.0 0.008784850078905839 0.0933149317526246
# 성공 chunk 비율: 0.008784850078905839
# 성공 chunk 시작 step 평균/표준편차: 630.4299401197604 202.5863300904515
